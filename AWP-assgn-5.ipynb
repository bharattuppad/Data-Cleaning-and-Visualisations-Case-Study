# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sal = pd.read_csv('Salaries.csv')
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %%
sal['JobTitle'][sal['EmployeeName']=='JOSEPH DRISCOLL']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sal['TotalPayBenefits'][sal['EmployeeName']=='JOSEPH DRISCOLL']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
a = sal['TotalPayBenefits'].max()
sal[sal['TotalPayBenefits']==a]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
b = sal['TotalPayBenefits'].min()
sal[sal['TotalPayBenefits']==b]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# Joe Lopez is getting paid in negative values. So it means that person probably owes money to the company which he/she needs to clear.

# %%
c = sal.groupby('Year')
c['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
e = sal.JobTitle.nunique()
print('No of Unique job Titles is: ',e)
# Out:
# No of Unique job Titles is:  2159

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
c.get_group(2013)['JobTitle'].value_counts().loc[lambda x:x==1]
# Out:
# Laboratory Technician I           1
# Sctry, Juv Probation Comm         1
# Drug Court Coordinator            1
# IS Operator-Journey               1
# Court Asst., Superior Court       1
#                                  ..
# Sr General Utility Mechanic       1
# Sprv Adult Prob Ofc (SFERS)       1
# Mayoral Staff XII                 1
# Pr Investigator, Tax Collector    1
# Senior Assessment Clerk           1
# Name: JobTitle, Length: 202, dtype: int64

# %%
len(c.get_group(2013)['JobTitle'].value_counts().loc[lambda x:x==1])
# Out:
# 202

# %%
sal['JobTitle'].str.find('Chief' | 'chief')
# Out:
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1
#          ..
# 148649   -1
# 148650   -1
# 148651   -1
# 148652   -1
# 148653   -1
# Name: JobTitle, Length: 148654, dtype: int64

# %%
sal['JobTitle'].str.find('CHIEF').value_counts()
# Out:
# -1     148450
#  0        101
#  10        85
#  7          8
#  17         5
#  13         3
#  6          2
# Name: JobTitle, dtype: int64

# %%
h=[]
for x in sal['JobTitle']:
    q=len(x)
    h.append(q)
print(h)
# Out:
# [46, 31, 31, 36, 44, 25, 34, 30, 34, 38, 48, 31, 27, 17, 34, 34, 17, 37, 34, 26, 26, 26, 25, 34, 25, 15, 25, 34, 36, 44, 27, 36, 17, 34, 34, 33, 34, 34, 34, 34, 34, 34, 44, 11, 30, 5, 34, 17, 36, 27, 34, 17, 25, 25, 37, 36, 17, 25, 27, 11, 27, 31, 37, 34, 34, 31, 48, 25, 36, 27, 17, 34, 49, 13, 34, 34, 34, 50, 25, 34, 27, 27, 34, 46, 37, 22, 34, 11, 18, 50, 34, 31, 25, 31, 34, 12, 11, 34, 22, 48, 34, 27, 11, 18, 11, 11, 34, 18, 18, 11, 11, 18, 48, 18, 18, 20, 17, 32, 34, 18, 25, 11, 22, 18, 18, 31, 11, 34, 25, 27, 50, 25, 18, 34, 34, 27, 21, 17, 49, 49, 49, 27, 32, 11, 34, 37, 18, 11, 27, 18, 11, 34, 34, 37, 14, 34, 32, 34, 34, 48, 18, 22, 12, 32, 22, 11, 18, 11, 13, 34, 27, 32, 25, 27, 34, 27, 27, 12, 22, 13, 34, 29, 12, 11, 34, 12, 30, 50, 18, 27, 32, 30, 34, 25, 27, 11, 35, 50, 11, 11, 11, 11, 25, 13, 11, 12, 32, 22, 34, 34, 34, 31, 25, 11, 31, 27, 18, 11, 22, 12, 18, 11, 36, 25, 16, 31, 22, 11, 17, 25, 18, 14, 22, 27, 27, 11, 18, 22, 22, 31, 31, 25, 34, 30, 18, 18, 50, 13, 31, 22
# ...

# %%
sal['title_len'] = h

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status  title_len
# ...

# %%
sal['title_len'].corr(sal['TotalPayBenefits'])
# Out:
# -0.03687844593260671

# %% [markdown]
# The correlation between title length and Total Pay Benefits is very weak negative
